# %% [markdown]
# ## **Importing necessary libraries**

# %%
from numpy import loadtxt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
nn_dataset = pd.read_csv('/content/drive/MyDrive/Datasets/class_assignment/nn_data.txt', header=None)
nn_dataset.shape
print(nn_dataset.head())
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
x = nn_dataset.iloc[:,0:8]
y = nn_dataset.iloc[:,8]

x.head()
# Out:
#    0    1   2   3    4     5      6   7
# 0  6  148  72  35    0  33.6  0.627  50
# 1  1   85  66  29    0  26.6  0.351  31
# 2  8  183  64   0    0  23.3  0.672  32
# 3  1   89  66  23   94  28.1  0.167  21
# 4  0  137  40  35  168  43.1  2.288  33

# %% [markdown]
# ## **Data Normalize(Scaling)**

# %%
cols_to_be_scale = [0,1,2,3,4,5,6,7]

scaler = preprocessing.MinMaxScaler()

x[cols_to_be_scale] = scaler.fit_transform(x[cols_to_be_scale])

x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.352941  0.743719  0.590164  0.353535  0.000000  0.500745  0.234415
# 1  0.058824  0.427136  0.540984  0.292929  0.000000  0.396423  0.116567
# 2  0.470588  0.919598  0.524590  0.000000  0.000000  0.347243  0.253629
# 3  0.058824  0.447236  0.540984  0.232323  0.111111  0.418778  0.038002
# 4  0.000000  0.688442  0.327869  0.353535  0.198582  0.642325  0.943638
#
#           7
# 0  0.483333
# 1  0.166667
# 2  0.183333
# 3  0.000000
# 4  0.200000

# %%
model = Sequential()
model.add(Dense(8, input_shape=(8,), activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x, y, epochs=200, batch_size=8)
# Out:
# Epoch 1/200
# 96/96 [==============================] - 1s 2ms/step - loss: 0.6699 - accuracy: 0.6510
# Epoch 2/200
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6575 - accuracy: 0.6497
# Epoch 3/200
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6451 - accuracy: 0.6523
# Epoch 4/200
# 96/96 [==============================] - 1s 7ms/step - loss: 0.6343 - accuracy: 0.6654
# Epoch 5/200
# 96/96 [==============================] - 0s 4ms/step - loss: 0.6222 - accuracy: 0.6654
# Epoch 6/200
# 96/96 [==============================] - 0s 4ms/step - loss: 0.6116 - accuracy: 0.6745
# Epoch 7/200
# 96/96 [==============================] - 0s 4ms/step - loss: 0.6030 - accuracy: 0.6927
# Epoch 8/200
# 96/96 [==============================] - 0s 4ms/step - loss: 0.5936 - accuracy: 0.6979
# Epoch 9/200
# 96/96 [==============================] - 0s 4ms/step - loss: 0.5851 - accuracy: 0.7018
# Epoch 10/200
# ...

# %%
_, accuracy = model.evaluate(x, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 1s 4ms/step - loss: 0.4265 - accuracy: 0.7826
# Accuracy: 78.26

# %%
predictions = (model.predict(x) > 0.5).astype(int)
for i in range(5):
	print(' %d (expected %d)' % ( predictions[i], y[i]))
# Out:
# 24/24 [==============================] - 0s 1ms/step
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
